# %% [markdown]
# This cell installs the matplotlib library needef for data visualizaiton in this project.

# %% [markdown]
# # 2. Dataset Overview

# %%
# 2. Imports and data loading
import matplotlib.pyplot as plt
print("matplotlib imported successfully")

import pandas as pd
print("pandas imported successfully")

import numpy as np
print("numpy imported successfully")

import plotly.graph_objects as go
print("plotly imported successfully")


df = pd.read_csv("data/covid19_patient_symptoms_diagnosis.csv")
rows, columns = df.shape

print("────────────────────────────────────────────────────────────────────" )
print("All imports successful!")
print(f"COVID-19 dataset loaded successfully: {rows} rows and {columns} columns.")
# Out:
# matplotlib imported successfully
# pandas imported successfully
# numpy imported successfully
# plotly imported successfully
# ────────────────────────────────────────────────────────────────────
# All imports successful!
# COVID-19 dataset loaded successfully: 5000 rows and 18 columns.

# %% [markdown]
# The COVID-19 patient symptoms and diagnosis dataset was loaded successfully.
# The data set has 5,000 rows and 18 columns.
# Each row represents a unique patient record.
# The dataset includes demographic information, symptom indicators, clinical measurements, and finally, COVID diagnostic result.
# This dataset was selected because it allows us to explore the relationship between patient symptoms, demographics, and COVID-19 outcomes.

# %% [markdown]
# # 3. Initial Data Inspection

# %%
# 3. Initial data inspection

print("--- First 5 Rows of the Dataset ---")
print(df.head())
print("\n--- Last 5 Rows of the Dataset ---")
print(df.tail())
print("\n--- Column Data Types ---")
print(df.dtypes)
print("\n--- Dataset Info (Null Counts & Types) ---")
df.info()
# Out:
# --- First 5 Rows of the Dataset ---
#    patient_id  age  gender  fever  dry_cough  sore_throat  fatigue  headache  \
# 0           1   52    Male      1          0            1        1         0
# 1           2   15    Male      0          0            0        1         1
# 2           3   72    Male      1          0            1        0         0
# 3           4   61  Female      0          0            1        1         1
# 4           5   21  Female      1          1            0        0         0
#
#    shortness_of_breath  loss_of_smell  loss_of_taste  oxygen_level  \
# 0                    0              0              0            98
# 1                    0              0              0            85
# 2                    1              0              1            99
# 3                    0              1              1            86
# 4                    1              0              1            90
#
# ...

# %% [markdown]
# The initial inspection reveals the dataset contains a mix of binary symptom columns (0 or 1),
# categorical columns (gender, comorbidity), and numerical columns (age, oxygen_level,
# body_temperature). No immediately obvious structural issues were detected in the column
# data types. The next steps will involve checking for missing values, duplicates, and outliers
# before proceeding with analysis.

# %% [markdown]
# ## 4. Demographic Summary

# %%
# 4. Basic demographic summary

total_records = len(df)
print("Total Records in Dataset:", total_records)

gender_summary = df['gender'].value_counts()
print("\n--- Gender Breakdown ---")
print(gender_summary)

mean_age = df['age'].mean()
print(f"\nMean Age of Dataset: {mean_age:.2f} (Rounded: {round(mean_age)})")
print("\n--- Age Descriptive Statistics ---")
print(df['age'].describe())
# Out:
# Total Records in Dataset: 5000
#
# --- Gender Breakdown ---
# gender
# Female    2514
# Male      2486
# Name: count, dtype: int64
#
# Mean Age of Dataset: 44.38 (Rounded: 44)
#
# --- Age Descriptive Statistics ---
# count    5000.000000
# mean       44.380600
# std        25.551632
# min         1.000000
# 25%        22.000000
# 50%        44.000000
# 75%        66.000000
# max        89.000000
# Name: age, dtype: float64

# %% [markdown]
# The dataset contains records from patients ranging across multiple age groups with a mean age
# of approximately 44 years. The gender breakdown shows a relatively balanced distribution
# between male and female patients. These demographic statistics establish the baseline
# profile of the patient population and will be referenced throughout the analysis when
# interpreting symptom and diagnosis patterns across different groups.

# %% [markdown]
# ## 5. Data Cleaning — Missing Values and Duplicates

# %%
# 5. Data cleaning — duplicates and missing values

print("Total Duplicate Rows:", df.duplicated().sum())

print("\n--- Missing Value Count per Column ---")
print(df.isnull().sum())

print("\nUnique values in comorbidity column:", df['comorbidity'].unique())
counts = df['comorbidity'].value_counts(dropna=False)
percent = df['comorbidity'].value_counts(normalize=True, dropna=False) * 100
print("\n--- Comorbidity Distribution (Before Cleaning) ---")
print(pd.DataFrame({'Count': counts, 'Percent': percent.round(2)}))

df_cleaned = df.copy()
df_cleaned['comorbidity'] = df_cleaned['comorbidity'].fillna("No Comorbidities")

print(f"\nMissing values BEFORE cleaning: {df['comorbidity'].isnull().sum()}")
print(f"Missing values AFTER cleaning:  {df_cleaned['comorbidity'].isnull().sum()}")

counts_clean = df_cleaned['comorbidity'].value_counts(dropna=False)
percent_clean = df_cleaned['comorbidity'].value_counts(normalize=True, dropna=False) * 100
print("\n--- Comorbidity Distribution (After Cleaning) ---")
print(pd.DataFrame({'Count': counts_clean, 'Percent': percent_clean.round(2)}))
# Out:
# Total Duplicate Rows: 0
#
# --- Missing Value Count per Column ---
# patient_id                 0
# age                        0
# gender                     0
# fever                      0
# dry_cough                  0
# sore_throat                0
# fatigue                    0
# headache                   0
# shortness_of_breath        0
# loss_of_smell              0
# loss_of_taste              0
# oxygen_level               0
# body_temperature           0
# comorbidity             2725
# travel_history             0
# contact_with_patient       0
# chest_pain                 0
# covid_result               0
# dtype: int64
#
# Unique values in comorbidity column: <StringArray>
# ['Diabetes', nan, 'Asthma', 'Heart Disease']
# Length: 4, dtype: str
#
# --- Comorbidity Distribution (Before Cleaning) ---
#                Count  Percent
# comorbidity
# NaN             2725    54.50
# Diabetes        1001    20.02
# Heart Disease    792    15.84
# Asthma           482     9.64
#
# ...

# %% [markdown]
# **Duplicates:** No duplicate rows were found in the dataset, confirming that each patient
# record is unique and no rows need to be removed on this basis.
#
# **Missing Values:** The only column with missing values is the comorbidity column, which
# contains 2,725 missing entries representing 54.5% of the dataset. All other columns are
# complete with zero missing values.
#
# **Why this Matters:** Rather than dropping the 2,725 rows with missing comorbidity values,
# we filled them with the label "No Comorbidities." This decision was made for two reasons.
# First, dropping over half the dataset would severely reduce the reliability and
# representativeness of our analysis. Second, the absence of a recorded comorbidity is itself
# clinically meaningful information indicating the patient has no known underlying condition.
# Replacing NaN with "No Comorbidities" preserves this information rather than discarding it.

# %% [markdown]
# ## 5. Data Cleaning — Missing Values and Duplicates (Visualization)

# %%
categories = counts_clean.index.tolist()
before_counts = [counts.get(cat, 0) for cat in categories]
after_counts = counts_clean.tolist()

x = np.arange(len(categories))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 6))

bars1 = ax.bar(x - width/2, before_counts, width, label='Before Cleaning', color='tomato')
bars2 = ax.bar(x + width/2, after_counts, width, label='After Cleaning', color='steelblue')

ax.set_title('Comorbidity Distribution Before and After Cleaning', fontsize=14)
ax.set_xlabel('Comorbidity Group', fontsize=12)
ax.set_ylabel('Patient Count', fontsize=12)
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 20,
            str(int(bar.get_height())), ha='center', va='bottom', fontsize=10)
for bar in bars2:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 20,
            str(int(bar.get_height())), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.savefig('figs/section5_comorbidity_distribution.png')
plt.show()

# %%
# Missing Values per Column
missing_values = df.isnull().sum()

plt.figure(figsize=(10, 5))
plt.bar(missing_values.index, missing_values.values, color='steelblue')

plt.title('Missing Values per Column')
plt.xlabel('Columns')
plt.ylabel('Missing Value Count')
plt.xticks(rotation=45, ha='right')

for i, val in enumerate(missing_values.values):
    plt.text(i, val + 10, str(val), ha='center', fontsize=9)

plt.tight_layout()
plt.savefig('figs/missing_values_per_column.png')
plt.show()

# %% [markdown]
# # 6. Outlier Detection — Age, Oxygen Level & Body Temperature

# %%
# 6. Outlier detection for age using IQR method


# --- Overall COVID Positive vs Negative ---
total = len(df_cleaned)
result_counts = df_cleaned['covid_result'].value_counts()
result_pct = df_cleaned['covid_result'].value_counts(normalize=True) * 100

print("=" * 40)
print("   OVERALL COVID-19 RESULT SUMMARY")
print("=" * 40)
print(f"  Positive (1): {result_counts[1]:>5}  ({result_pct[1]:.2f}%)")
print(f"  Negative (0): {result_counts[0]:>5}  ({result_pct[0]:.2f}%)")
print(f"  {'─' * 30}")
print(f"  Total:        {total:>5}  (100.00%)")
print("=" * 40)
print("\n")
print("--- Age / Oxygen Level / Body Temperature Descriptive Statistics ---")
numerical_cols = ['age', 'oxygen_level', 'body_temperature']

for col in numerical_cols:
    print(f"--- {col.upper()} Descriptive Statistics ---")
    print(df_cleaned[col].describe(), '\n')

    Q1 = df_cleaned[col].quantile(0.25)
    Q3 = df_cleaned[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df_cleaned[(df_cleaned[col] < lower_bound) | (df_cleaned[col] > upper_bound)]

    print('-' * 35)
    print(f"  {col.upper()} OUTLIER ANALYSIS")
    print('-' * 35)
    print(f"Quartile 1 (25%):  {Q1:>10.2f}")
    print(f"Quartile 3 (75%):  {Q3:>10.2f}")
    print(f"IQR:               {IQR:>10.2f}")
    print('-' * 35)
    print(f"Lower Bound:       {lower_bound:>10.2f}")
    print(f"Upper Bound:       {upper_bound:>10.2f}")
    print('-' * 35)
    print(f"Outliers Found:    {len(outliers):>10}")
    print('=' * 35)
    print()
# Out:
# ...
#    OVERALL COVID-19 RESULT SUMMARY
# ...
#   Positive (1):  2600  (52.00%)
#   Negative (0):  2400  (48.00%)
#   ──────────────────────────────
#   Total:         5000  (100.00%)
# ...
#
#
# --- Age / Oxygen Level / Body Temperature Descriptive Statistics ---
# --- AGE Descriptive Statistics ---
# count    5000.000000
# mean       44.380600
# std        25.551632
# min         1.000000
# 25%        22.000000
# 50%        44.000000
# 75%        66.000000
# max        89.000000
# Name: age, dtype: float64
#
# -----------------------------------
#   AGE OUTLIER ANALYSIS
# -----------------------------------
# Quartile 1 (25%):       22.00
# Quartile 3 (75%):       66.00
# IQR:                    44.00
# -----------------------------------
# Lower Bound:           -44.00
# Upper Bound:           132.00
# -----------------------------------
# Outliers Found:             0
# ...
#
# --- OXYGEN_LEVEL Descriptive Statistics ---
# count    5000.000000
# mean       91.934200
# std         4.300275
# ...

# %% [markdown]
# We applied the Interquartile Range (IQR) method to detect outliers across all three
# numerical columns in the dataset: age, oxygen level, and body temperature. This method
# flags any value that falls below Q1 - 1.5 times the IQR or above Q3 + 1.5 times the
# IQR as a potential outlier.
#
# **Finding: Zero outliers were detected across all three columns!**
# All patient ages,
# oxygen readings, and body temperatures fall within statistically reasonable ranges,
# confirming the dataset is clean and no rows need to be removed on this basis.
#
# # Things to Consider
# **Normal Threshold:**
# A normal threshold is the baseline measurement for a healthy individual. Two clinically
# significant observations emerged from the descriptive statistics when comparing the
# dataset against these thresholds.
#
# **Oxygen Level — Below Normal Threshold:**
# The normal threshold for oxygen level is 95%. A healthy individual should have an oxygen
# saturation between 95% and 100%. The mean oxygen level across all patients in this dataset
# is 91.9%, which falls below the normal threshold of 95%. This indicates that the average
# patient in this dataset was already experiencing reduced oxygen saturation, which is one
# of the most recognized warning signs of COVID-19 and is consistent with a population of
# patients presenting with active respiratory distress.
#
# **Body Temperature — Above Normal Threshold:**
# The normal threshold for body temperature is 37°C or 98.6°F. A healthy individual should
# have a body temperature at or below this value. The mean body temperature across all
# patients in this dataset is 38.5°C or 101.3°F, which sits above the normal threshold.
# This indicates that the average patient in this dataset was presenting with a fever at
# the time of their COVID-19 diagnosis, consistent with fever being one of the most
# commonly reported symptoms of COVID-19.
#
# These patterns will be explored further in the statistical analysis and modeling sections
# of this project.

# %%
df_cleaned['body_temperature_f'] = (df_cleaned['body_temperature'] * 9/5) + 32

fig, axes = plt.subplots(1, 4, figsize=(18, 5))

df_cleaned['age'].plot(kind='box', ax=axes[0], title='Age (years)')
df_cleaned['oxygen_level'].plot(kind='box', ax=axes[1], title='Oxygen Level (%)')
df_cleaned['body_temperature'].plot(kind='box', ax=axes[2], title='Body Temperature (°C)')
df_cleaned['body_temperature_f'].plot(kind='box', ax=axes[3], title='Body Temperature (°F)')

axes[1].axhline(y=95, color='red', linestyle='--', linewidth=1.5, label='Normal: 95%')
axes[1].axhline(y=91.9, color='orange', linestyle='--', linewidth=1.5, label='Mean: 91.9%')
axes[1].legend(fontsize=9)

axes[2].axhline(y=37, color='red', linestyle='--', linewidth=1.5, label='Normal: 37°C')
axes[2].axhline(y=38.5, color='orange', linestyle='--', linewidth=1.5, label='Mean: 38.5°C')
axes[2].legend(fontsize=9)

axes[3].axhline(y=98.6, color='red', linestyle='--', linewidth=1.5, label='Normal: 98.6°F')
axes[3].axhline(y=101.3, color='orange', linestyle='--', linewidth=1.5, label='Mean: 101.3°F')
axes[3].legend(fontsize=9)

plt.suptitle('Outlier Detection — Numerical Columns')
plt.tight_layout()
plt.savefig('figs/section6_outlier_detection.png')
plt.show()

# %% [markdown]
# # 7. Age Distribution Visualization

# %%
# 7. Age Count
age_count = df_cleaned['age'].value_counts().sort_index()
print("---Patient Count per Age---")
print(age_count)
print(f"\nTotal Patient: {age_count.sum()}")
plt.figure(figsize=(18, 6))
plt.bar(age_count.index, age_count.values, color='steelblue')
plt.title('Patient Count by Age')
plt.xlabel('Age')
plt.ylabel('Patient Count')
plt.xticks(range(0, 90, 5))
plt.tight_layout()
plt.show()
plt.savefig('figs/section7_age_count.png')
plt.show()
# Out:
# ---Patient Count per Age---
# age
# 1     56
# 2     57
# 3     61
# 4     56
# 5     55
#       ..
# 85    50
# 86    66
# 87    65
# 88    54
# 89    55
# Name: count, Length: 89, dtype: int64
#
# Total Patient: 5000

# %% [markdown]
# The bar chart above displays the count of patients at each individual age. The distribution
# appears relatively spread across the age range with no single age group dominating the
# dataset. This visualization confirms the earlier finding that no age outliers are present,
# as there are no extreme spikes or gaps at the boundaries of the distribution. The spread
# across age groups makes this dataset well suited for age-based subgroup analysis.

# %% [markdown]
# # 8. Age Category Binning

# %%
# 8. Age group aggregation into 6 life stage categories

bins = [0, 18, 35, 50, 60, 80, 100]
labels = ['Minors (0-17)', 'Young Adult (18-34)', 'Adult (35-49)',
          'Middle Aged (50-59)', 'Senior (60-79)', 'Elderly (80+)']

df_cleaned['age_categories'] = pd.cut(df_cleaned['age'], bins=bins, labels=labels, right=False)
category_counts = df_cleaned['age_categories'].value_counts().sort_index()
total_patients = category_counts.sum()

print("--- Patient Count per Age Category ---")
print(category_counts)
print(f"\nTotal Patients Across All Groups: {total_patients}")
# Out:
# --- Patient Count per Age Category ---
# age_categories
# Minors (0-17)           975
# Young Adult (18-34)     976
# Adult (35-49)           861
# Middle Aged (50-59)     560
# Senior (60-79)         1084
# Elderly (80+)           544
# Name: count, dtype: int64
#
# Total Patients Across All Groups: 5000

# %% [markdown]
# To enable more impactful group-level analysis, patients were binned into five age
# categories based on standard demographic groupings:
# - Minors (0-17)
# - Young Adults (18-34)
# - Adults (35-49)
# - Middle Aged (50-59)
# - Senior (60+)
#
# This categorization allows us to compare symptom patterns, COVID positive rates, and
# clinical measurements across life stage groups rather than individual ages, which produces
# more interpretable and actionable insights.

# %%
fig, ax = plt.subplots(figsize=(10, 5))

category_counts.plot(kind='bar', ax=ax, color='pink', edgecolor='green')

ax.set_title('Patient Count by Age Category')
ax.set_xlabel('Age Category')
ax.set_ylabel('Patient Count')
ax.tick_params(axis='x', rotation=45)

for bar in ax.patches:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 10,
            str(int(bar.get_height())), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.savefig('figs/section8_age_categories.png')
plt.show()

# %% [markdown]
# # 9. Age and Gender Breakdown

# %%
# 9. Age and gender breakdown by group
print("--- Age Statistics by Gender ---")
print(df_cleaned.groupby('gender')['age'].agg(['mean', 'median', 'min', 'max', 'count']))

gender_within_age = pd.crosstab(df_cleaned['age_categories'], df_cleaned['gender'], normalize='index') * 100
age_within_gender = pd.crosstab(df_cleaned['age_categories'], df_cleaned['gender'], normalize='columns') * 100

print("\n--- Gender Split WITHIN Each Age Category (%) ---")
print(gender_within_age.map('{:.2f}%'.format))

print("\n--- Age Distribution WITHIN Each Gender (%) ---")
print(age_within_gender.map('{:.2f}%'.format))

# --- Overall Positive & Negative ---
total = len(df_cleaned)
result_counts = df_cleaned['covid_result'].value_counts()
result_pct = df_cleaned['covid_result'].value_counts(normalize=True) * 100

print("\n--- Overall COVID Result (Entire Dataset) ---")
print(f"Positive (1): {result_counts[1]:>6}  ({result_pct[1]:.2f}%)")
print(f"Negative (0): {result_counts[0]:>6}  ({result_pct[0]:.2f}%)")
print(f"Total:        {total:>6}")

# --- Positive & Negative by Gender ---
print("\n--- COVID Result Counts by Gender ---")
print(df_cleaned.groupby('gender')['covid_result'].value_counts())

print("\n--- COVID Result % WITHIN Each Gender ---")
result_by_gender = pd.crosstab(df_cleaned['gender'], df_cleaned['covid_result'], normalize='index') * 100
print(result_by_gender.map('{:.2f}%'.format))

# --- Positive & Negative by Age Category ---
print("\n--- COVID Result Counts by Age Category ---")
print(df_cleaned.groupby('age_categories')['covid_result'].value_counts())

print("\n--- COVID Result % WITHIN Each Age Category ---")
result_by_age = pd.crosstab(df_cleaned['age_categories'], df_cleaned['covid_result'], normalize='index') * 100
print(result_by_age.map('{:.2f}%'.format))

# --- Combined: Age Category × Gender × Result ---
print("\n--- COVID Result % by Age Category AND Gender ---")
result_by_age_gender = pd.crosstab(
    [df_cleaned['age_categories'], df_cleaned['gender']],
    df_cleaned['covid_result'],
    normalize='index'
) * 100
print(result_by_age_gender.map('{:.2f}%'.format))
# Out:
# --- Age Statistics by Gender ---
#              mean  median  min  max  count
# gender
# Female  44.638425    45.0    1   89   2514
# Male    44.119871    44.0    1   89   2486
#
# --- Gender Split WITHIN Each Age Category (%) ---
# gender               Female    Male
# age_categories
# Minors (0-17)        48.62%  51.38%
# Young Adult (18-34)  50.92%  49.08%
# Adult (35-49)        52.03%  47.97%
# Middle Aged (50-59)  47.68%  52.32%
# Senior (60-79)       51.38%  48.62%
# Elderly (80+)        49.82%  50.18%
#
# --- Age Distribution WITHIN Each Gender (%) ---
# gender               Female    Male
# age_categories
# Minors (0-17)        18.85%  20.15%
# Young Adult (18-34)  19.77%  19.27%
# Adult (35-49)        17.82%  16.61%
# Middle Aged (50-59)  10.62%  11.79%
# Senior (60-79)       22.16%  21.20%
# Elderly (80+)        10.78%  10.98%
#
# --- COVID Result Counts by Gender ---
# gender  covid_result
# Female  1               1294
#         0               1220
# ...

# %% [markdown]
# This section examines how age and gender intersect across the dataset. The cross tabulation
# between age categories and gender shows the proportion of male and female patients within
# each age group. This breakdown helps identify whether any age group skews heavily toward
# one gender, which could influence how we interpret symptom and diagnosis patterns within
# those groups.

# %%
fig, ax = plt.subplots(figsize=(10, 5))

gender_within_age.plot(kind='bar', ax=ax, edgecolor='navy')

ax.set_title('Gender Split Within Each Age Category (%)')
ax.set_xlabel('Age Category')
ax.set_ylabel('Percentage (%)')
ax.tick_params(axis='x', rotation=45)
ax.legend(title='Gender')

plt.tight_layout()
plt.savefig('figs/section9_age_gender_breakdown.png')
plt.show()

# %% [markdown]
# # 10. Overall Symptom Frequency

# %%
# 10. Overall symptom frequency and rate by COVID result

symptoms = ['fever', 'dry_cough', 'sore_throat', 'fatigue', 'headache',
            'shortness_of_breath', 'loss_of_smell', 'loss_of_taste', 'chest_pain']

symptom_counts = df_cleaned[symptoms].sum().sort_values(ascending=False)
symptom_pct = (symptom_counts / len(df_cleaned) * 100).round(2)

print('--- Overall Symptom Frequency ---')
print(pd.DataFrame({'Count': symptom_counts, 'Percent (%)': symptom_pct}))

symptom_by_result = df_cleaned.groupby('covid_result')[symptoms].mean() * 100
symptom_by_result = symptom_by_result.rename(index={0: 'Negative', 1: 'Positive'})

print('\n--- Symptom Rate by COVID Result (%) ---')
print(symptom_by_result.T.round(2))

# %%
x = np.arange(len(symptom_counts))
width = 0.25

fig, ax = plt.subplots(figsize=(12, 6))

ax.bar(x - width, symptom_pct.reindex(symptom_counts.index).values,
       width, label='Overall', color='steelblue')
ax.bar(x,         symptom_by_result.loc['Negative'].reindex(symptom_counts.index).values,
       width, label='COVID Negative', color='green')
ax.bar(x + width, symptom_by_result.loc['Positive'].reindex(symptom_counts.index).values,
       width, label='COVID Positive', color='tomato')

ax.set_title('Symptom Rate — Overall vs COVID Positive vs Negative')
ax.set_xlabel('Symptom')
ax.set_ylabel('Rate (%)')
ax.set_xticks(x)
ax.set_xticklabels(symptom_counts.index, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.savefig('figs/symptom_frequency_by_covid_result.png')
plt.show()

# %% [markdown]
# The symptom frequency table shows how commonly each symptom appeared across all patients
# in the dataset. Some symptoms appear far more frequently than others, suggesting they may
# be stronger indicators of COVID-19 presence. This frequency baseline will be used later
# to compare symptom rates between COVID positive and negative patient groups to identify
# which symptoms carry the most diagnostic weight.

# %% [markdown]
# # 11. Symptom Rate by Age Group

# %%
# 11. Symptom analysis broken down by age group

symptom_by_age = df_cleaned.groupby('age_categories', observed=False)[symptoms].mean() * 100

print("--- Symptom Rate by Age Group (%) ---")
print(symptom_by_age.round(2))

print("\n--- Most Common Symptom Per Age Group ---")
print(symptom_by_age.idxmax(axis=1))

print("\n--- Which Age Group Has the Highest Rate of Each Symptom ---")
for symptom in symptoms:
    top_group = symptom_by_age[symptom].idxmax()
    top_pct = symptom_by_age[symptom].max().round(2)
    print(f"{symptom:<25} → {top_group} ({top_pct}%)")

# %% [markdown]
# This table shows the percentage of patients in each age category who reported each symptom.
# Comparing symptom rates across age groups helps identify whether certain symptoms are more
# prevalent in older or younger patients. The most common symptom per age group is also
# identified to highlight dominant patterns within each life stage category.

# %%
# Interactive: Symptom Rate by Age Group (Plotly)
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "notebook"

symptoms = ['fever','dry_cough','sore_throat','fatigue','headache',
            'shortness_of_breath','loss_of_smell','loss_of_taste','chest_pain']

symptom_by_age = df_cleaned.groupby('age_categories')[symptoms].mean() * 100

age_order = ['Minors (0-17)', 'Young Adult (18-34)', 'Adult (35-49)',
             'Middle Aged (50-59)', 'Senior (60-79)', 'Elderly (80+)']

symptom_by_age = symptom_by_age.reindex(age_order)

fig1 = go.Figure()

for symptom in symptoms:
    fig1.add_trace(go.Bar(
        name=symptom,
        x=age_order,
        y=symptom_by_age[symptom].round(2),
        hovertemplate='<b>%{x}</b><br>' + symptom + ': %{y:.2f}%<extra></extra>'
    ))

fig1.update_layout(
    barmode='group',
    title='Symptom Rate by Age Group (%) — Interactive',
    xaxis_title='Age Group',
    yaxis_title='Symptom Rate (%)',
    legend_title='Symptom',
    height=550,
    hovermode='x unified'
)

fig1.show()
fig1.write_html("figs/symptom_rate_by_age_interactive.html")
fig1.write_image("figs/symptom_rate_by_age.png")
print("Saved!")

# %% [markdown]
# # 12. COVID Positive Rate and Symptom Burden by Age Group

# %%
# 12. COVID positive rate and symptom burden by age group

df_cleaned['symptom_count'] = df_cleaned[symptoms].sum(axis=1)

print("--- Avg Symptom Count & COVID Positive Rate by Age Group ---")
age_summary = df_cleaned.groupby('age_categories', observed=False).agg(
    Avg_Symptoms=('symptom_count', 'mean'),
    Positive_Rate=('covid_result', 'mean'),
    Patient_Count=('patient_id', 'count')
)
age_summary['Positive_Rate'] = (age_summary['Positive_Rate'] * 100).round(2)
age_summary['Avg_Symptoms'] = age_summary['Avg_Symptoms'].round(2)
print(age_summary)

# %% [markdown]
# This summary table shows the average symptom count and COVID positive rate for each age
# category. Higher average symptom counts in a group suggest a more severe disease
# presentation. Differences in COVID positive rates across age groups help identify which
# populations were most affected and will inform the hypothesis testing section of this project.

# %%
# Interactive: COVID Positive Rate by Age Group (Plotly)
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "notebook"

age_order = ['Minors (0-17)', 'Young Adult (18-34)', 'Adult (35-49)',
             'Middle Aged (50-59)', 'Senior (60-79)', 'Elderly (80+)']

covid_by_age = df_cleaned.groupby('age_categories')['covid_result'].mean() * 100
covid_by_age = covid_by_age.reindex(age_order).round(2)
mean_rate = covid_by_age.mean().round(2)

fig2 = go.Figure()

fig2.add_trace(go.Bar(
    x=age_order,
    y=covid_by_age.values,
    name='COVID Positive Rate',
    marker_color=['tomato' if v > mean_rate else 'steelblue' for v in covid_by_age.values],
    hovertemplate='<b>%{x}</b><br>Positive Rate: %{y:.2f}%<br>' +
                  f'vs Mean ({mean_rate}%): ' + '%{customdata}<extra></extra>',
    customdata=[f'+{round(v - mean_rate, 2)}%' if v > mean_rate
                else f'{round(v - mean_rate, 2)}%' for v in covid_by_age.values]
))

fig2.add_hline(
    y=mean_rate,
    line_dash='dash',
    line_color='black',
    line_width=2,
    annotation_text=f'Overall Mean: {mean_rate}%',
    annotation_position='top right',
    annotation_font_size=12
)

fig2.update_layout(
    title='COVID Positive Rate by Age Group (%)',
    xaxis_title='Age Group',
    yaxis_title='COVID Positive Rate (%)',
    height=550,
    yaxis=dict(range=[0, 100]),
    hovermode='x unified',
    legend_title='Legend',
    annotations=[
        dict(
            text='(Red) Above mean  (Blue) Below mean',
            x=0.01, y=1.08,
            xref='paper', yref='paper',
            showarrow=False,
            font=dict(size=11)
        )
    ],
    updatemenus=[
        dict(
            type='buttons',
            direction='left',
            x=0.01, y=1.15,
            xanchor='left',
            buttons=[
                dict(
                    label='Show All',
                    method='update',
                    args=[{'visible': [True, True]}]
                ),
                dict(
                    label='Hide Mean Line',
                    method='relayout',
                    args=[{'shapes': []}]
                ),
            ]
        )
    ]
)

fig2.show()
fig2.write_html("figs/covid_positive_by_age_interactive.html")
fig2.write_image("figs/covid_positive_by_age.png")
print("Saved!")

# %% [markdown]
# # 13. Gender Demographic Summary

# %%
# 13. Gender demographic summary

gender_demo = df_cleaned.groupby('gender').agg(
    Patient_Count=('patient_id', 'count'),
    Avg_Age=('age', 'mean'),
    Min_Age=('age', 'min'),
    Max_Age=('age', 'max'),
    Positive_Rate=('covid_result', 'mean')
)
gender_demo['Avg_Age'] = gender_demo['Avg_Age'].round(2)
gender_demo['Positive_Rate'] = (gender_demo['Positive_Rate'] * 100).round(2)

print("--- Gender Demographic Summary ---")
print(gender_demo)

# %% [markdown]
# The gender demographic summary compares patient count, average age, age range, and COVID
# positive rate between male and female patients. A balanced gender distribution reduces the
# risk of gender bias skewing our findings and allows for reliable comparisons between groups
# throughout the analysis.

# %% [markdown]
# # 14. Symptom Rate by Gender

# %%
# 14. Symptom frequency broken down by gender

symptom_by_gender = df_cleaned.groupby('gender')[symptoms].mean() * 100

print("--- Symptom Rate by Gender (%) ---")
print(symptom_by_gender.T.round(2))

print("\n--- Most Common Symptom Per Gender ---")
print(symptom_by_gender.idxmax(axis=1))

# %% [markdown]
# This table shows the percentage of male and female patients who reported each symptom.
# Differences in symptom rates between genders may reflect biological or behavioral differences
# in how COVID-19 presents. The most common symptom per gender is also identified to highlight
# any dominant patterns between the two groups.

# %% [markdown]
# # 15. COVID Positive Rate and Symptom Burden by Gender

# %%
# 15. COVID positive rate and symptom burden by gender

gender_summary = df_cleaned.groupby('gender').agg(
    Avg_Symptoms=('symptom_count', 'mean'),
    Positive_Rate=('covid_result', 'mean'),
    Patient_Count=('patient_id', 'count')
)
gender_summary['Positive_Rate'] = (gender_summary['Positive_Rate'] * 100).round(2)
gender_summary['Avg_Symptoms'] = gender_summary['Avg_Symptoms'].round(2)

print("--- Avg Symptom Count & COVID Positive Rate by Gender ---")
print(gender_summary)

# %% [markdown]
# This table compares average symptom count and COVID positive rate between male and female
# patients. If one gender shows a notably higher positive rate or symptom burden, this
# difference will be formally tested in the statistical hypothesis testing section using
# an appropriate test such as a chi-square or t-test.

# %% [markdown]
# # 16. Symptom Dominance by Gender

# %%
# 16. Symptom dominance by gender showing which gender reports each symptom more

print("--- Which Gender Has the Highest Rate of Each Symptom ---")
for symptom in symptoms:
    top_gender = symptom_by_gender[symptom].idxmax()
    top_pct = symptom_by_gender[symptom].max().round(2)
    diff = (symptom_by_gender[symptom].max() - symptom_by_gender[symptom].min()).round(2)
    print(f"{symptom:<25} → {top_gender} ({top_pct}%)  |  Difference: {diff}%")

# %% [markdown]
# This analysis identifies which gender reported the highest rate of each individual symptom
# and calculates the difference between the two groups. A large difference indicates that the
# symptom may be more strongly associated with one gender, which is useful context for both
# clinical interpretation and feature selection in the modeling section.

# %% [markdown]
# # 17. Symptom Rate by Gender and COVID Result Combined

# %%
# 17. Symptom rate by gender and COVID result combined

print("--- Symptom Rate by Gender & COVID Result (%) ---")
gender_covid_symptoms = df_cleaned.groupby(['gender', 'covid_result'])[symptoms].mean() * 100


display_df = gender_covid_symptoms.copy()
display_df = display_df.rename(index={0: 'Negative', 1: 'Positive'}, level='covid_result')  # FIXED
print(display_df.round(2).T)

# %% [markdown]
# This combined breakdown shows symptom rates split by both gender and COVID result
# simultaneously. This allows us to see whether symptom patterns between positive and negative
# patients differ by gender, adding a layer of depth to the symptom analysis beyond what
# single-variable groupings reveal.

# %% [markdown]
# # 18. Comorbidity Group Demographic Summary

# %%
# 18. Comorbidity demographic summary

comorbidity_demo = df_cleaned.groupby('comorbidity').agg(
    Patient_Count=('patient_id', 'count'),
    Avg_Age=('age', 'mean'),
    Min_Age=('age', 'min'),
    Max_Age=('age', 'max'),
    Positive_Rate=('covid_result', 'mean')
)
comorbidity_demo['Avg_Age'] = comorbidity_demo['Avg_Age'].round(2)
comorbidity_demo['Positive_Rate'] = (comorbidity_demo['Positive_Rate'] * 100).round(2)

print("--- Comorbidity Demographic Summary ---")
print(comorbidity_demo)

# %% [markdown]
# Patients were grouped by comorbidity status to examine how underlying health conditions
# relate to age, COVID positive rate, and overall patient distribution. The four groups are
# No Comorbidities, Diabetes, Heart Disease, and Asthma. This comparison allows us to
# determine whether patients with pre-existing conditions experience higher COVID positive
# rates, which has important implications for understanding COVID-19 risk factors.

# %% [markdown]
# # 19. Symptom Rate by Comorbidity Group

# %%
# 19. Symptom frequency broken down by comorbidity group

symptom_by_comorbidity = df_cleaned.groupby('comorbidity')[symptoms].mean() * 100

print("--- Symptom Rate by Comorbidity Group (%) ---")
print(symptom_by_comorbidity.T.round(2))

print("\n--- Most Common Symptom Per Comorbidity Group ---")
print(symptom_by_comorbidity.idxmax(axis=1))

# %% [markdown]
# This table shows the percentage of patients in each comorbidity group who reported each
# symptom. Differences in symptom rates across groups suggest that underlying health conditions
# may influence how COVID-19 presents in patients. Groups with notably higher rates of specific
# symptoms compared to others may warrant closer clinical attention and further statistical
# testing.

# %% [markdown]
# # 20. COVID Positive Rate and Symptom Burden by Comorbidity Group

# %%
# 20. COVID positive rate and symptom burden by comorbidity group

comorbidity_summary = df_cleaned.groupby('comorbidity').agg(  
    Avg_Symptoms=('symptom_count', 'mean'),
    Positive_Rate=('covid_result', 'mean'),
    Patient_Count=('patient_id', 'size')
)
comorbidity_summary['Positive_Rate'] = (comorbidity_summary['Positive_Rate'] * 100).round(2)
comorbidity_summary['Avg_Symptoms'] = comorbidity_summary['Avg_Symptoms'].round(2)
print('--- Avg Symptom Count & COVID Positive Rate by Comorbidity ---')
print(comorbidity_summary)

# %% [markdown]
# This summary table combines average symptom count and COVID positive rate for each
# comorbidity group. If patients with Diabetes or Heart Disease show meaningfully higher
# positive rates than those with no comorbidity, this finding supports the clinical
# understanding that pre-existing conditions are a significant COVID-19 risk factor.

# %% [markdown]
# # 21. Symptom Dominance by Comorbidity Group

# %%
# 21. Symptom dominance by comorbidity showing which group reports each symptom most

print("--- Which Comorbidity Group Has the Highest Rate of Each Symptom ---")
for symptom in symptoms:
    top_group = symptom_by_comorbidity[symptom].idxmax()
    top_pct = symptom_by_comorbidity[symptom].max().round(2)
    diff = (symptom_by_comorbidity[symptom].max() - symptom_by_comorbidity[symptom].min()).round(2)
    print(f"{symptom:<25} → {top_group} ({top_pct}%)  |  Difference: {diff}%")

# %% [markdown]
# This analysis identifies which comorbidity group reported the highest rate of each individual
# symptom and quantifies the spread between the highest and lowest groups. A large difference
# indicates that the symptom may be particularly linked to a specific underlying condition,
# which is valuable clinical context for interpreting the modeling results later.

# %% [markdown]
# # 22. COVID Result Demographic Summary

# %%
# 20) COVID result demographic summary comparing positive vs negative patients

covid_demo = df_cleaned.groupby('covid_result').agg(
    Patient_Count=('patient_id', 'count'),
    Avg_Age=('age', 'mean'),
    Min_Age=('age', 'min'),
    Max_Age=('age', 'max'),
    Avg_Symptoms=('symptom_count', 'mean'),
    Avg_Oxygen=('oxygen_level', 'mean'),
    Avg_Temp=('body_temperature', 'mean')
)
covid_demo = covid_demo.rename(index={0: 'Negative', 1: 'Positive'})  # FIXED
covid_demo['Avg_Age'] = covid_demo['Avg_Age'].round(2)
covid_demo['Avg_Symptoms'] = covid_demo['Avg_Symptoms'].round(2)
covid_demo['Avg_Oxygen'] = covid_demo['Avg_Oxygen'].round(2)
covid_demo['Avg_Temp'] = covid_demo['Avg_Temp'].round(2)

print('--- COVID Result Demographic Summary ---')
print(covid_demo)

# %% [markdown]
# Patients were split into COVID positive and COVID negative groups to compare their demographic
# and clinical profiles. Key metrics compared include average age, age range, average symptom
# count, average oxygen level, and average body temperature. These comparisons help establish
# whether positive patients differ meaningfully from negative patients on measurable clinical
# dimensions, laying the groundwork for statistical hypothesis testing.

# %% [markdown]
# # 23. Symptom Rate by COVID Result

# %%
# 23. Symptom frequency and difference between positive and negative patients

symptom_by_covid = df_cleaned.groupby('covid_result')[symptoms].mean() * 100
symptom_by_covid = symptom_by_covid.rename(index={0: 'Negative', 1: 'Positive'})  # FIXED

print('--- Symptom Rate by COVID Result (%) ---')
print(symptom_by_covid.T.round(2))

print('\n--- Symptom Difference: Positive vs Negative (%) ---')
symptom_diff = (symptom_by_covid.loc['Positive'] - symptom_by_covid.loc['Negative']).round(2)
print(symptom_diff.sort_values(ascending=False))

# %% [markdown]
# This table compares the rate of each symptom between COVID positive and negative patients.
# The difference column highlights which symptoms appear significantly more often in positive
# patients compared to negative ones. Symptoms with the largest positive differences are the
# strongest candidates for being COVID indicators and will be examined further in the hypothesis
# testing and modeling sections.

# %% [markdown]
# # 24. Strongest Symptom Predictors of a Positive COVID Result

# %%
# 24. Strongest symptom predictors of a positive COVID result

print("--- COVID Positive Rate WITH vs WITHOUT Each Symptom ---")
predictor_results = []
for symptom in symptoms:
    with_symptom = df_cleaned[df_cleaned[symptom] == 1]['covid_result'].mean() * 100
    without_symptom = df_cleaned[df_cleaned[symptom] == 0]['covid_result'].mean() * 100
    difference = with_symptom - without_symptom
    predictor_results.append({
        'Symptom': symptom,
        'With (%)': round(with_symptom, 2),
        'Without (%)': round(without_symptom, 2),
        'Difference': round(difference, 2)
    })

print(pd.DataFrame(predictor_results).set_index('Symptom').sort_values('Difference', ascending=False))

# %% [markdown]
# This analysis calculates the COVID positive rate among patients who reported each symptom
# versus those who did not. A large difference between the two rates indicates that the symptom
# is a strong predictor of a positive COVID result. These findings directly inform which
# features will be prioritized as input variables in the modeling section of this project.

# %% [markdown]
# # 25. Oxygen Level Grouping Using Clinical Thresholds

# %%
# 25. Oxygen level group creation using clinical thresholds

oxy_bins = [0, 85, 90, 95, 101]
oxy_labels = ['Severe (<85)', 'Moderate (85-89)', 'Mild (90-94)', 'Normal (95-100)']

df_cleaned['oxygen_group'] = pd.cut(df_cleaned['oxygen_level'], bins=oxy_bins, labels=oxy_labels, right=False)

oxygen_counts = df_cleaned['oxygen_group'].value_counts().sort_index()
print("--- Patient Count per Oxygen Level Group ---")
print(oxygen_counts)
print(f"\nTotal Patients: {oxygen_counts.sum()}")

# %% [markdown]
# Patients were grouped into four oxygen level categories based on established clinical
# thresholds. Severe is defined as below 85 percent, Moderate as 85 to 89 percent, Mild as
# 90 to 94 percent, and Normal as 95 to 100 percent. These groupings reflect real world medical
# standards for assessing respiratory health and allow us to analyze how oxygen saturation
# relates to COVID diagnosis and symptom burden in a clinically meaningful way.

# %% [markdown]
# # 26. Oxygen Level Group Demographic Summary

# %%
# 26. Oxygen level group demographic summary

oxygen_demo = df_cleaned.groupby('oxygen_group', observed=False).agg(
    Patient_Count=('patient_id', 'count'),
    Avg_Age=('age', 'mean'),
    Positive_Rate=('covid_result', 'mean'),
    Avg_Symptoms=('symptom_count', 'mean'),
    Avg_Temp=('body_temperature', 'mean')
)
oxygen_demo['Avg_Age'] = oxygen_demo['Avg_Age'].round(2)
oxygen_demo['Positive_Rate'] = (oxygen_demo['Positive_Rate'] * 100).round(2)
oxygen_demo['Avg_Symptoms'] = oxygen_demo['Avg_Symptoms'].round(2)
oxygen_demo['Avg_Temp'] = oxygen_demo['Avg_Temp'].round(2)
oxygen_demo = oxygen_demo.fillna(0)

print("--- Oxygen Level Group Demographic Summary ---")
print(oxygen_demo)

# %% [markdown]
# The demographic summary broken down by oxygen level group reveals how patient age, symptom
# count, body temperature, and COVID positive rate vary across respiratory health categories.
# Patients in the Severe and Moderate groups are expected to show higher COVID positive rates
# and greater symptom burdens. Any patterns observed here will be explored further in the
# symptom and COVID result analyses that follow.

# %% [markdown]
# # 27. Symptom Rate by Oxygen Level Group

# %%
# 27. Symptom frequency and dominance broken down by oxygen level group

symptom_by_oxygen = df_cleaned.groupby('oxygen_group', observed=True)[symptoms].mean() * 100

print("--- Symptom Rate by Oxygen Level Group (%) ---")
print(symptom_by_oxygen.round(2))

print("\n--- Most Common Symptom Per Oxygen Level Group ---")
print(symptom_by_oxygen.idxmax(axis=1))

print("\n--- Which Oxygen Group Has the Highest Rate of Each Symptom ---")
for symptom in symptoms:
    top_group = symptom_by_oxygen[symptom].idxmax()
    top_pct = symptom_by_oxygen[symptom].max().round(2)
    diff = (symptom_by_oxygen[symptom].max() - symptom_by_oxygen[symptom].min()).round(2)
    print(f"{symptom:<25} → {top_group} ({top_pct}%)  |  Difference: {diff}%")

# %% [markdown]
# This table shows how symptom rates vary across the four oxygen level groups. Patients with
# lower oxygen levels are expected to report higher rates of respiratory symptoms such as
# shortness of breath and chest pain. The dominance analysis identifies which oxygen group
# reports the highest rate of each symptom and quantifies the difference between the highest
# and lowest groups.

# %% [markdown]
# # 28. COVID Positive Rate and Symptom Burden by Oxygen Level Group

# %%
# 28. COVID positive rate and symptom burden by oxygen level group

oxygen_summary = df_cleaned.groupby('oxygen_group', observed=True).agg(
    Avg_Symptoms=('symptom_count', 'mean'),
    Positive_Rate=('covid_result', 'mean'),
    Patient_Count=('patient_id', 'count')
)
oxygen_summary['Positive_Rate'] = (oxygen_summary['Positive_Rate'] * 100).round(2)
oxygen_summary['Avg_Symptoms'] = oxygen_summary['Avg_Symptoms'].round(2)

print("--- Avg Symptom Count & COVID Positive Rate by Oxygen Level Group ---")
print(oxygen_summary)

# %% [markdown]
# This final oxygen level summary table combines average symptom count, COVID positive rate,
# and patient count for each oxygen group. A clear trend is expected where lower oxygen
# saturation groups carry higher COVID positive rates and greater symptom burdens. This
# relationship between oxygen level and COVID diagnosis is one of the most clinically
# significant findings in this exploratory analysis and will be revisited in the hypothesis
# testing and modeling sections.
